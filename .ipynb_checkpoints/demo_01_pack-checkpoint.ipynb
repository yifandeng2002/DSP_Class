# %%
from struct import pack

# %% [markdown]
# convert to binery

# %%
pack('B',0)
# Out:
# b'\x00'

# %%
pack('B',1)
# Out:
# b'\x01'

# %%
type(_)
# Out:
# bytes

# %%
f = open('file-01','wb')
s = pack('B',4)
check = f.write(s)
check
f.close()

# %%
f = open('file-02','wb')

# %%
f.write( pack('B',6) )
f.write( pack('B',15) )
f.write( pack('B',32) )
f.close()

# %%
f = open('file-03','wb')

# %%
for i in range(0, 256):
    f.write(pack('B', i))
f.close()

# %%
pack('BBB',5,6,7)
# Out:
# b'\x05\x06\x07'

# %%
3*'B'
# Out:
# 'BBB'

# %%
pack('h',1) #two bytes
# Out:
# b'\x01\x00'

# %%
pack('h',266)
# Out:
# b'\n\x01'

# %%
pack('h',-266)
# Out:
# b'\xf6\xfe'

# %%
pack('h',32767) #max
# Out:
# b'\xff\x7f'

# %%
2**15
# Out:
# 32768

# %%
pack('i',0) # 32bit
# Out:
# b'\x00\x00\x00\x00'

# %%
pack('i', 2**31-1) # max
# Out:
# b'\xff\xff\xff\x7f'

# %%
pack('i', -2**31) # min
# Out:
# b'\x00\x00\x00\x80'
